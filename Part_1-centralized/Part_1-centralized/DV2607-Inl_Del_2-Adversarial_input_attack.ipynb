# %% [markdown]
# # Inlämningsuppgift: Del 2 - Adversarial input attack

# %% [markdown]
# Förnamn Efternamn \
# akronym@student.bth.se
#
# Förnamn Efternamn \
# akronym@student.bth.se

# %% [markdown]
# # Instruktioner

# %% [markdown]
# Ändra notebookens platshållare så som era namn- och mailuppgifter samt instruktioner i de olika avsnitten.

# %% [markdown]
# Notebookens underrubriker på nivå 3 (###) är bara ett enkelt exempel på hur er implementation kan delas upp. Ni bör skapa egna rubriker anpassade efter er implementation men lämna alla nivå 1 (#) och 2-rubriker (##) som de är. En viktig del inom data-science är att kunna presentera sina metoder och resultat på ett tydligt sätt. **En ostrukturerad och otydlig notebook kan påverka betygsättningen.**

# %% [markdown]
# Notera att t.ex. hyperparameter-tuning och annan optimisering för prestanda inte är nödvändigt i denna uppgift. Så länge modellen fungerar märkvärt bättre än ett "coin flip" så räcker det att ni väljer era hyperparametrar manuellt.

# %% [markdown]
# # Uppgiften

# %% [markdown]
# Uppgiften går ut på att göra så att bilden på koalan nedan klassificeras som en traktor istället. Givetvis ska bilden på koalan se helt oförändrad ut för det mänskliga ögat då attacken är genomförd. Nedan följer Pythonkod som läser in de båda bilderna som uppgiften bygger på samt läser in en ResNet50-modell som klassiciferar bilderna. Saknar ni några Python-paket, t.ex. TensorFlow så installera dem med en pakethanterarare, t.ex. pip

# %% [markdown]
# ## Beskrivning av adversarial input attacker

# %% [markdown]
# Börja med att förklara vad denna typ av attacker är och hur de fungerar i rapportens sektion 2.1.

# %% [markdown]
# ## Nedan följer kod för att läsa in bilderna och klassificera dem med ResNet50 modellen

# %%
from matplotlib import pyplot as plt
import numpy as np

import tensorflow as tf
import keras
from tensorflow.keras.applications.resnet50 import ResNet50, preprocess_input
from tensorflow.keras.preprocessing import image

from art.estimators.classification import KerasClassifier
from art.attacks.evasion import BoundaryAttack
from art.utils import to_categorical

tf.compat.v1.disable_eager_execution()

print(f"TensorFlow: {tf.__version__}")

# %%
# Loads the pretrained ResNet50 model
model = ResNet50(weights='imagenet')

# %%
# Load the two images (koala & tractor)
init_image = image.load_img("images/koala.jpeg", target_size=(224, 224))
init_image = image.img_to_array(init_image)

target_image = image.load_img("images/tractor.jpeg", target_size=(224, 224))
target_image = image.img_to_array(target_image)

class_lookup = {105: "koala", 866: "tractor"}

# %%
init_class_id = np.argmax(model.predict(np.array([init_image])))
print(f"Init image class label: {init_class_id} ({class_lookup[init_class_id]})")
plt.imshow(init_image.astype(np.uint))
plt.show()

target_class_id = np.argmax(model.predict(np.array([target_image])))
print(f"Target image class label: {target_class_id} ({class_lookup[target_class_id]})")
plt.imshow(target_image.astype(np.uint))
plt.show()

# %% [markdown]
# ## Implementation av er attack

# %% [markdown]
# Beskriv i er rapport vad just er valda attack kallas och i detalj hur den fungerar (sektion 2.2 i rapporten). Beskriv även kort vilka bibliotek ni använder för att implementera den.

# %% [markdown]
# ## Er kod för attacken

# %% [markdown]
# I cellerna nedan lägger ni in er egen kod för att genomföra attacken.

# %% [markdown]
# ### Bibliotek

# %%
# Samla era import statements här e.g.
# import matplotlib.pyplot as plt
# import numpy as np
# import pandas as pd
# ...

# %% [markdown]
# ### Egna funktioner

# %%
# Samla era egna funktioner relaterade till attacken här
# Funktionerna ska kort beskrivas med docstrings och kommentarer så att man förstår syftet och implementationen
# Blir det många bör ni bryta ut dessa i en separat fil

# %% [markdown]
# ### Förberedelser

# %%
ones = np.ones([224, 224, 3])
imagenet_means = np.ones([224, 224, 3])
imagenet_means[...,0].fill(103.939)
imagenet_means[...,1].fill(116.779)
imagenet_means[...,2].fill(123.68)
#show image
plt.imshow(imagenet_means.astype(np.uint8))
plt.show()

# %% [markdown]
# ### Modellering

# %%
# E.g. träning
classifier = KerasClassifier(model=model,clip_values=(0, 255))

# %% [markdown]
# ### Attack

# %% [markdown]
# Beskriv attackprocessen kortfattat här

# %%
# Attackutförande -
attack = BoundaryAttack(estimator=classifier, targeted=True, max_iter=500)
X = np.array([init_image])
Y = to_categorical([target_class_id], 1000)
x_adv = np.array([target_image])

for i in range(10):
    x_adv = attack.generate(X, Y,x_adv_init=x_adv)

    init_class_id = np.argmax(model.predict(np.array([x_adv[0]])))
    print("Iteration: ", i," MSE: ",np.linalg.norm(np.reshape(x_adv[0] - init_image[..., ::-1], [-1])), "Class ID: ",init_class_id)
    adv = x_adv[0].astype(np.uint)
    plt.imshow(adv)
    plt.show()
# Out:
# Boundary attack - iterations: 100%|██████████| 500/500 [08:30<00:00,  1.02s/it]
# Boundary attack: 100%|██████████| 1/1 [08:30<00:00, 510.02s/it]
# Iteration:  0  MSE:  13347.889 Class ID:  866
# Boundary attack - iterations: 100%|██████████| 500/500 [08:48<00:00,  1.06s/it]
# Boundary attack: 100%|██████████| 1/1 [08:48<00:00, 528.07s/it]
# Iteration:  1  MSE:  10061.702 Class ID:  866
# Boundary attack - iterations: 100%|██████████| 500/500 [08:35<00:00,  1.03s/it]
# Boundary attack: 100%|██████████| 1/1 [08:35<00:00, 515.94s/it]
# Iteration:  2  MSE:  8088.4014 Class ID:  866
# Boundary attack - iterations: 100%|██████████| 500/500 [08:37<00:00,  1.03s/it]
# Boundary attack: 100%|██████████| 1/1 [08:37<00:00, 517.46s/it]
# Iteration:  3  MSE:  6939.865 Class ID:  866
# Boundary attack - iterations: 100%|██████████| 500/500 [08:53<00:00,  1.07s/it]
# Boundary attack: 100%|██████████| 1/1 [08:53<00:00, 533.49s/it]
# Iteration:  4  MSE:  6194.417 Class ID:  866
# Boundary attack - iterations: 100%|██████████| 500/500 [08:54<00:00,  1.07s/it]
# Boundary attack: 100%|██████████| 1/1 [08:54<00:00, 534.92s/it]
# Iteration:  5  MSE:  5741.4194 Class ID:  866
# Boundary attack:   0%|          | 0/1 [00:00<?, ?it/s]
# Boundary attack - iterations:  95%|█████████▌| 476/500 [09:16<00:28,  1.17s/it]
# Boundary attack:   0%|          | 0/1 [09:16<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[102], line 8
#       5 x_adv = np.array([target_image])
#       7 for i in range(10):
# ----> 8     x_adv = attack.generate(X, Y,x_adv_init=x_adv)
#      10     init_class_id = np.argmax(model.predict(np.array([x_adv[0]])))
#      11     print("Iteration: ", i," MSE: ",np.linalg.norm(np.reshape(x_adv[0] - init_image[..., ::-1], [-1])), "Class ID: ",init_class_id)
#
# File c:\Users\tobbe\Documents\BTH\Ai-scurety\Security-in-AI-systems\.venv\lib\site-packages\art\attacks\evasion\boundary.py:164, in BoundaryAttack.generate(self, x, y, **kwargs)
#     162 for ind, val in enumerate(tqdm(x_adv, desc="Boundary attack", disable=not self.verbose)):
#     163     if self.targeted:
# --> 164         x_adv[ind] = self._perturb(
#     165             x=val,
#     166             y=y[ind],
#     167             y_p=preds[ind],
#     168             init_pred=init_preds[ind],
#     169             adv_init=x_adv_init[ind],
#     170             clip_min=clip_min,
#     171             clip_max=clip_max,
#     172         )
#     173     else:
#     174         x_adv[ind] = self._perturb(
#     175             x=val,
#     176             y=-1,
#    (...)
#     181             clip_max=clip_max,
#     182         )
#
# File c:\Users\tobbe\Documents\BTH\Ai-scurety\Security-in-AI-systems\.venv\lib\site-packages\art\attacks\evasion\boundary.py:223, in BoundaryAttack._perturb(self, x, y, y_p, init_pred, adv_init, clip_min, clip_max)
#     220     return x
#     222 # If an initial adversarial example found, then go with boundary attack
# --> 223 x_adv = self._attack(
#     224     initial_sample[0],
#     225     x,
#     226     y_p,
#     227     initial_sample[1],
#     228     self.delta,
#     229     self.epsilon,
#     230     clip_min,
#     231     clip_max,
#     232 )
#     234 return x_adv
#
# File c:\Users\tobbe\Documents\BTH\Ai-scurety\Security-in-AI-systems\.venv\lib\site-packages\art\attacks\evasion\boundary.py:268, in BoundaryAttack._attack(self, initial_sample, original_sample, y_p, target, initial_delta, initial_epsilon, clip_min, clip_max)
#     265 self.curr_adv = x_adv
#     267 # Main loop to wander around the boundary
# --> 268 for _ in trange(self.max_iter, desc="Boundary attack - iterations", disable=not self.verbose):
#     269     # Trust region method to adjust delta
#     270     for _ in range(self.num_trial):
#     271         potential_advs_list: list[np.ndarray] = []
#
# File c:\Users\tobbe\Documents\BTH\Ai-scurety\Security-in-AI-systems\.venv\lib\site-packages\tqdm\std.py:1191, in tqdm.__iter__(self)
#    1189 dt = cur_t - last_print_t
#    1190 if dt >= mininterval and cur_t >= min_start_t:
# -> 1191     self.update(n - last_print_n)
#    1192     last_print_n = self.last_print_n
#    1193     last_print_t = self.last_print_t
#
# File c:\Users\tobbe\Documents\BTH\Ai-scurety\Security-in-AI-systems\.venv\lib\site-packages\tqdm\std.py:1242, in tqdm.update(self, n)
#    1240     self._ema_dn(dn)
#    1241     self._ema_dt(dt)
# -> 1242 self.refresh(lock_args=self.lock_args)
#    1243 if self.dynamic_miniters:
#    1244     # If no `miniters` was specified, adjust automatically to the
#    1245     # maximum iteration rate seen so far between two prints.
#    1246     # e.g.: After running `tqdm.update(5)`, subsequent
#    1247     # calls to `tqdm.update()` will only cause an update after
#    1248     # at least 5 more iterations.
#    1249     if self.maxinterval and dt >= self.maxinterval:
#
# File c:\Users\tobbe\Documents\BTH\Ai-scurety\Security-in-AI-systems\.venv\lib\site-packages\tqdm\std.py:1347, in tqdm.refresh(self, nolock, lock_args)
#    1345     else:
#    1346         self._lock.acquire()
# -> 1347 self.display()
#    1348 if not nolock:
#    1349     self._lock.release()
#
# File c:\Users\tobbe\Documents\BTH\Ai-scurety\Security-in-AI-systems\.venv\lib\site-packages\tqdm\std.py:1495, in tqdm.display(self, msg, pos)
#    1493 if pos:
#    1494     self.moveto(pos)
# -> 1495 self.sp(self.__str__() if msg is None else msg)
#    1496 if pos:
#    1497     self.moveto(-pos)
#
# File c:\Users\tobbe\Documents\BTH\Ai-scurety\Security-in-AI-systems\.venv\lib\site-packages\tqdm\std.py:459, in tqdm.status_printer.<locals>.print_status(s)
#     457 def print_status(s):
#     458     len_s = disp_len(s)
# --> 459     fp_write('\r' + s + (' ' * max(last_len[0] - len_s, 0)))
#     460     last_len[0] = len_s
#
# File c:\Users\tobbe\Documents\BTH\Ai-scurety\Security-in-AI-systems\.venv\lib\site-packages\tqdm\std.py:453, in tqdm.status_printer.<locals>.fp_write(s)
#     451 def fp_write(s):
#     452     fp.write(str(s))
# --> 453     fp_flush()
#
# File c:\Users\tobbe\Documents\BTH\Ai-scurety\Security-in-AI-systems\.venv\lib\site-packages\tqdm\utils.py:196, in DisableOnWriteError.disable_on_exception.<locals>.inner(*args, **kwargs)
#     194 def inner(*args, **kwargs):
#     195     try:
# --> 196         return func(*args, **kwargs)
#     197     except OSError as e:
#     198         if e.errno != 5:
#
# File c:\Users\tobbe\Documents\BTH\Ai-scurety\Security-in-AI-systems\.venv\lib\site-packages\ipykernel\iostream.py:609, in OutStream.flush(self)
#     607     self.pub_thread.schedule(evt.set)
#     608     # and give a timeout to avoid
# --> 609     if not evt.wait(self.flush_timeout):
#     610         # write directly to __stderr__ instead of warning because
#     611         # if this is happening sys.stderr may be the problem.
#     612         print("IOStream.flush timed out", file=sys.__stderr__)
#     613 else:
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.10_3.10.3056.0_x64__qbz5n2kfra8p0\lib\threading.py:607, in Event.wait(self, timeout)
#     605 signaled = self._flag
#     606 if not signaled:
# --> 607     signaled = self._cond.wait(timeout)
#     608 return signaled
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.10_3.10.3056.0_x64__qbz5n2kfra8p0\lib\threading.py:324, in Condition.wait(self, timeout)
#     322 else:
#     323     if timeout > 0:
# --> 324         gotit = waiter.acquire(True, timeout)
#     325     else:
#     326         gotit = waiter.acquire(False)
#
# KeyboardInterrupt:

# %% [markdown]
# ### Attackresultat

# %% [markdown]
# Summera och förklara era attackresultat i flytande text här

# %%
# Presentera attackens resultat m.h.a. kod här
init_class_id = np.argmax(model.predict(np.array([adv])))
print(model.predict(np.array([adv]))[0][init_class_id])
print(f"Init image class label: {init_class_id} ({class_lookup[init_class_id]})")
plt.imshow(adv.astype(np.uint))
plt.show()

#Orginalbild
init_class_id = np.argmax(model.predict(np.array([init_image])))
print(model.predict(np.array([init_image]))[0][init_class_id])
print(f"Init image class label: {init_class_id} ({class_lookup[init_class_id]})")
plt.imshow(init_image.astype(np.uint))
plt.show()

# %% [markdown]
# ## Skyddsåtgärder

# %% [markdown]
# Beskriv (i rapportens sektion 2.3) vilka säkerhetsåtgärd(er) ni valt som lämpliga för att skydda mot er attack. Motivera varför ni valt just de(n) metod(erna).

# %% [markdown]
# ## Implementation av skyddsåtgärder (frivilligt endast för A eller B)

# %% [markdown]
# Nedan fyller ni i er kod som implementerar skyddsmekanismen mot er attackmetod. Skriv även en summering av vad skyddsresultatet blev när ni implementerade metoden (beskriv detta i rapportens del 2.4).

# %% [markdown]
# ### Egna funktioner

# %%
# Samla era egna funktioner relaterade till säkerhetsåtgärden här
# Funktionerna ska kort beskrivas med docstrings och kommentarer så att man förstår syftet och implementationen
# Blir det många bör ni bryta ut dessa i en separat fil

# %% [markdown]
# ### Förberedelser

# %%
# E.g. skapande av ny modell, etc.

# %% [markdown]
# ### Skydd

# %% [markdown]
# Beskriv säkerhetsåtgärden kortfattat här

# %%
# Implementation av skyddsåtgärd

# %% [markdown]
# ### Skyddsresultat

# %% [markdown]
# Bevisa och förklara era skyddsresultat i flytande text här

# %%
# Presentera skyddåtgärdens resultat m.h.a. kod här

# %% [markdown]
# # Referenser

# %% [markdown]
# Lista era referenser här. E.g. var ni hittat information om attacken, skyddsåtgärder eller bibliotekets dokumentation/repository.
