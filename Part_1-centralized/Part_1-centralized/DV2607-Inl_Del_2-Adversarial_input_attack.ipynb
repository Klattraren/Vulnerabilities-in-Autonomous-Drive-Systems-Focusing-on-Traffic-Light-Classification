# %% [markdown]
# # Inlämningsuppgift: Del 2 - Adversarial input attack

# %% [markdown]
# Förnamn Efternamn \
# akronym@student.bth.se
#
# Förnamn Efternamn \
# akronym@student.bth.se

# %% [markdown]
# # Instruktioner

# %% [markdown]
# Ändra notebookens platshållare så som era namn- och mailuppgifter samt instruktioner i de olika avsnitten.

# %% [markdown]
# Notebookens underrubriker på nivå 3 (###) är bara ett enkelt exempel på hur er implementation kan delas upp. Ni bör skapa egna rubriker anpassade efter er implementation men lämna alla nivå 1 (#) och 2-rubriker (##) som de är. En viktig del inom data-science är att kunna presentera sina metoder och resultat på ett tydligt sätt. **En ostrukturerad och otydlig notebook kan påverka betygsättningen.**

# %% [markdown]
# Notera att t.ex. hyperparameter-tuning och annan optimisering för prestanda inte är nödvändigt i denna uppgift. Så länge modellen fungerar märkvärt bättre än ett "coin flip" så räcker det att ni väljer era hyperparametrar manuellt.

# %% [markdown]
# # Uppgiften

# %% [markdown]
# Uppgiften går ut på att göra så att bilden på koalan nedan klassificeras som en traktor istället. Givetvis ska bilden på koalan se helt oförändrad ut för det mänskliga ögat då attacken är genomförd. Nedan följer Pythonkod som läser in de båda bilderna som uppgiften bygger på samt läser in en ResNet50-modell som klassiciferar bilderna. Saknar ni några Python-paket, t.ex. TensorFlow så installera dem med en pakethanterarare, t.ex. pip

# %% [markdown]
# ## Beskrivning av adversarial input attacker

# %% [markdown]
# Börja med att förklara vad denna typ av attacker är och hur de fungerar i rapportens sektion 2.1.

# %% [markdown]
# ## Nedan följer kod för att läsa in bilderna och klassificera dem med ResNet50 modellen

# %%
from matplotlib import pyplot as plt
import numpy as np

import tensorflow as tf
import keras
from tensorflow.keras.applications.resnet50 import ResNet50, preprocess_input
from tensorflow.keras.preprocessing import image

from art.estimators.classification import KerasClassifier
from art.attacks.evasion import BoundaryAttack
from art.utils import to_categorical

tf.compat.v1.disable_eager_execution()

print(f"TensorFlow: {tf.__version__}")
# Out:
# TensorFlow: 2.10.0

# %%
# Loads the pretrained ResNet50 model
model = ResNet50(weights='imagenet')
# Out:
# WARNING:tensorflow:From c:\Users\tobbe\Documents\BTH\Ai-scurety\Security-in-AI-systems\.venv\lib\site-packages\keras\layers\normalization\batch_normalization.py:562: _colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.

# %%
# Load the two images (koala & tractor)
init_image = image.load_img("images/koala.jpeg", target_size=(224, 224))
init_image = image.img_to_array(init_image)

target_image = image.load_img("images/tractor.jpeg", target_size=(224, 224))
target_image = image.img_to_array(target_image)

class_lookup = {105: "koala", 866: "tractor"}

# %%
init_class_id = np.argmax(model.predict(np.array([init_image])))
print(f"Init image class label: {init_class_id} ({class_lookup[init_class_id]})")
plt.imshow(init_image.astype(np.uint))
plt.show()

target_class_id = np.argmax(model.predict(np.array([target_image])))
print(f"Target image class label: {target_class_id} ({class_lookup[target_class_id]})")
plt.imshow(target_image.astype(np.uint))
plt.show()
# Out:
# c:\Users\tobbe\Documents\BTH\Ai-scurety\Security-in-AI-systems\.venv\lib\site-packages\keras\engine\training_v1.py:2356: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates=self.state_updates,
# Init image class label: 105 (koala)
# Target image class label: 866 (tractor)

# %% [markdown]
# ## Implementation av er attack

# %% [markdown]
# Beskriv i er rapport vad just er valda attack kallas och i detalj hur den fungerar (sektion 2.2 i rapporten). Beskriv även kort vilka bibliotek ni använder för att implementera den.

# %% [markdown]
# ## Er kod för attacken

# %% [markdown]
# I cellerna nedan lägger ni in er egen kod för att genomföra attacken.

# %% [markdown]
# ### Bibliotek

# %%
# Samla era import statements här e.g.
# import matplotlib.pyplot as plt
# import numpy as np
# import pandas as pd
# ...
import cv2 as cv

# %% [markdown]
# ### Egna funktioner

# %%
# Samla era egna funktioner relaterade till attacken här
# Funktionerna ska kort beskrivas med docstrings och kommentarer så att man förstår syftet och implementationen
# Blir det många bör ni bryta ut dessa i en separat fil

# %% [markdown]
# ### Förberedelser

# %% [markdown]
# ### Modellering

# %%
# E.g. träning, Använder en generell modell som en wrapper för att kunna använda ART
classifier = KerasClassifier(model=model,clip_values=(0, 255))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[41], line 2
#       1 # E.g. träning, Använder en generell modell som en wrapper för att kunna använda ART
# ----> 2 classifier = Classifier(model=model,clip_values=(0, 255))
#
# NameError: name 'Classifier' is not defined

# %% [markdown]
# ### Attack

# %% [markdown]
# Beskriv attackprocessen kortfattat här

# %%
# Attackutförande -
attack = BoundaryAttack(estimator=classifier, targeted=True, max_iter=1000)
X = np.array([init_image])

#Imagenet har 1000 classer enligt https://deeplearning.cms.waikato.ac.nz/user-guide/class-maps/IMAGENET/
Y = to_categorical([target_class_id], 1000)
x_adv = np.array([target_image])

#Beräknar euclidisk distans mellan bilderna
print("Iteration: ", 0," L2: ",np.linalg.norm(target_image - init_image), "Class ID: ",init_class_id)
plt.imshow(target_image.astype(np.uint))
plt.show()

#Kör 10 iterationer för att kunna plotta progressionen av attacken visuellt
for i in range(5):
    x_adv = attack.generate(X, Y,x_adv_init=x_adv)

    init_class_id = np.argmax(model.predict(np.array([x_adv[0]])))
    print("Iteration: ", (i+1)*1000," L2: ",np.linalg.norm(x_adv - init_image), "Class ID: ",init_class_id)
    adv = x_adv[0].astype(np.uint)
    plt.imshow(adv)
    plt.show()

#Save the adversarial image
cv.imwrite("images/adv_tractor.jpeg", adv)
# Out:
# Iteration:  0  L2:  44266.117 Class ID:  866
# Boundary attack - iterations: 100%|██████████| 1000/1000 [17:17<00:00,  1.04s/it]
# Boundary attack: 100%|██████████| 1/1 [17:17<00:00, 1037.34s/it]
# Iteration:  1000  L2:  44266.117 Class ID:  866
# Boundary attack - iterations: 100%|██████████| 1000/1000 [16:49<00:00,  1.01s/it]
# Boundary attack: 100%|██████████| 1/1 [16:49<00:00, 1009.82s/it]
# Iteration:  2000  L2:  44266.117 Class ID:  866
# Boundary attack - iterations: 100%|██████████| 1000/1000 [16:33<00:00,  1.01it/s]
# Boundary attack: 100%|██████████| 1/1 [16:33<00:00, 993.72s/it]
# Iteration:  3000  L2:  44266.117 Class ID:  866
# Boundary attack - iterations:  87%|████████▋ | 870/1000 [14:31<02:10,  1.00s/it]
# Boundary attack:   0%|          | 0/1 [14:31<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[14], line 16
#      14 #Kör 10 iterationer för att kunna plotta progressionen av attacken visuellt
#      15 for i in range(5):
# ---> 16     x_adv = attack.generate(X, Y,x_adv_init=x_adv)
#      18     init_class_id = np.argmax(model.predict(np.array([x_adv[0]])))
#      19     print("Iteration: ", (i+1)*1000," L2: ",np.linalg.norm(target_image - init_image), "Class ID: ",init_class_id)
#
# File c:\Users\tobbe\Documents\BTH\Ai-scurety\Security-in-AI-systems\.venv\lib\site-packages\art\attacks\evasion\boundary.py:164, in BoundaryAttack.generate(self, x, y, **kwargs)
#     162 for ind, val in enumerate(tqdm(x_adv, desc="Boundary attack", disable=not self.verbose)):
#     163     if self.targeted:
# --> 164         x_adv[ind] = self._perturb(
#     165             x=val,
#     166             y=y[ind],
#     167             y_p=preds[ind],
#     168             init_pred=init_preds[ind],
#     169             adv_init=x_adv_init[ind],
#     170             clip_min=clip_min,
#     171             clip_max=clip_max,
#     172         )
#     173     else:
#     174         x_adv[ind] = self._perturb(
#     175             x=val,
#     176             y=-1,
#    (...)
#     181             clip_max=clip_max,
#     182         )
#
# File c:\Users\tobbe\Documents\BTH\Ai-scurety\Security-in-AI-systems\.venv\lib\site-packages\art\attacks\evasion\boundary.py:223, in BoundaryAttack._perturb(self, x, y, y_p, init_pred, adv_init, clip_min, clip_max)
#     220     return x
#     222 # If an initial adversarial example found, then go with boundary attack
# --> 223 x_adv = self._attack(
#     224     initial_sample[0],
#     225     x,
#     226     y_p,
#     227     initial_sample[1],
#     228     self.delta,
#     229     self.epsilon,
#     230     clip_min,
#     231     clip_max,
#     232 )
#     234 return x_adv
#
# File c:\Users\tobbe\Documents\BTH\Ai-scurety\Security-in-AI-systems\.venv\lib\site-packages\art\attacks\evasion\boundary.py:308, in BoundaryAttack._attack(self, initial_sample, original_sample, y_p, target, initial_delta, initial_epsilon, clip_min, clip_max)
#     305 potential_advs = x_advs + perturb
#     306 potential_advs = np.clip(potential_advs, clip_min, clip_max)
#     307 preds = np.argmax(
# --> 308     self.estimator.predict(potential_advs, batch_size=self.batch_size),
#     309     axis=1,
#     310 )
#     312 if self.targeted:
#     313     satisfied = preds == target
#
# File c:\Users\tobbe\Documents\BTH\Ai-scurety\Security-in-AI-systems\.venv\lib\site-packages\art\estimators\classification\classifier.py:75, in InputFilter.__init__.<locals>.make_replacement.<locals>.replacement_function(self, *args, **kwargs)
#      73 if len(args) > 0:
#      74     args = tuple(lst)
# ---> 75 return fdict[func_name](self, *args, **kwargs)
#
# File c:\Users\tobbe\Documents\BTH\Ai-scurety\Security-in-AI-systems\.venv\lib\site-packages\art\estimators\classification\keras.py:547, in KerasClassifier.predict(self, x, batch_size, training_mode, **kwargs)
#     545     predictions = self._model(x_preprocessed, training=training_mode)
#     546 else:
# --> 547     predictions = self._model.predict(x_preprocessed, batch_size=batch_size)
#     549 # Apply postprocessing
#     550 predictions = self._apply_postprocessing(preds=predictions, fit=False)
#
# File c:\Users\tobbe\Documents\BTH\Ai-scurety\Security-in-AI-systems\.venv\lib\site-packages\keras\engine\training_v1.py:1058, in Model.predict(self, x, batch_size, verbose, steps, callbacks, max_queue_size, workers, use_multiprocessing)
#    1055 self._check_call_args("predict")
#    1057 func = self._select_training_loop(x)
# -> 1058 return func.predict(
#    1059     self,
#    1060     x=x,
#    1061     batch_size=batch_size,
#    1062     verbose=verbose,
#    1063     steps=steps,
#    1064     callbacks=callbacks,
#    1065     max_queue_size=max_queue_size,
#    1066     workers=workers,
#    1067     use_multiprocessing=use_multiprocessing,
#    1068 )
#
# File c:\Users\tobbe\Documents\BTH\Ai-scurety\Security-in-AI-systems\.venv\lib\site-packages\keras\engine\training_arrays_v1.py:801, in ArrayLikeTrainingLoop.predict(self, model, x, batch_size, verbose, steps, callbacks, **kwargs)
#     797 batch_size = model._validate_or_infer_batch_size(batch_size, steps, x)
#     798 x, _, _ = model._standardize_user_data(
#     799     x, check_steps=True, steps_name="steps", steps=steps
#     800 )
# --> 801 return predict_loop(
#     802     model,
#     803     x,
#     804     batch_size=batch_size,
#     805     verbose=verbose,
#     806     steps=steps,
#     807     callbacks=callbacks,
#     808 )
#
# File c:\Users\tobbe\Documents\BTH\Ai-scurety\Security-in-AI-systems\.venv\lib\site-packages\keras\engine\training_arrays_v1.py:419, in model_iteration(model, inputs, targets, sample_weights, batch_size, epochs, verbose, callbacks, val_inputs, val_targets, val_sample_weights, shuffle, initial_epoch, steps_per_epoch, validation_steps, validation_freq, mode, validation_in_fit, prepared_feed_values_from_dataset, steps_name, **kwargs)
#     414 callbacks._call_batch_hook(
#     415     mode, "begin", batch_index, batch_logs
#     416 )
#     418 # Get outputs.
# --> 419 batch_outs = f(ins_batch)
#     420 if not isinstance(batch_outs, list):
#     421     batch_outs = [batch_outs]
#
# File c:\Users\tobbe\Documents\BTH\Ai-scurety\Security-in-AI-systems\.venv\lib\site-packages\keras\backend.py:4577, in GraphExecutionFunction.__call__(self, inputs)
#    4567 if (
#    4568     self._callable_fn is None
#    4569     or feed_arrays != self._feed_arrays
#    (...)
#    4573     or session != self._session
#    4574 ):
#    4575     self._make_callable(feed_arrays, feed_symbols, symbol_vals, session)
# -> 4577 fetched = self._callable_fn(*array_vals, run_metadata=self.run_metadata)
#    4578 self._call_fetch_callbacks(fetched[-len(self._fetches) :])
#    4579 output_structure = tf.nest.pack_sequence_as(
#    4580     self._outputs_structure,
#    4581     fetched[: len(self.outputs)],
#    4582     expand_composites=True,
#    4583 )
#
# File c:\Users\tobbe\Documents\BTH\Ai-scurety\Security-in-AI-systems\.venv\lib\site-packages\tensorflow\python\client\session.py:1481, in BaseSession._Callable.__call__(self, *args, **kwargs)
#    1479 try:
#    1480   run_metadata_ptr = tf_session.TF_NewBuffer() if run_metadata else None
# -> 1481   ret = tf_session.TF_SessionRunCallable(self._session._session,
#    1482                                          self._handle, args,
#    1483                                          run_metadata_ptr)
#    1484   if run_metadata:
#    1485     proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# KeyboardInterrupt:

# %% [markdown]
# ### Attackresultat

# %% [markdown]
# Summera och förklara era attackresultat i flytande text här

# %%
# Presentera attackens resultat m.h.a. kod här
#Läser in bilden för att spara resuser om man startar om kernellen
adv_image = image.load_img("images/adv.png", target_size=(224, 224))
adv_image = image.img_to_array(adv_image)


init_class_id = np.argmax(model.predict(np.array([adv_image])))
print(f"Init image class label: {init_class_id} ({class_lookup[init_class_id]})")
plt.imshow(adv_image.astype(np.uint))
plt.title(f"Attackerad Bild, Klassifiering: {class_lookup[init_class_id]} ({init_class_id})")
plt.show()

#Orginalbild
init_class_id = np.argmax(model.predict(np.array([init_image])))
print(f"Init image class label: {init_class_id} ({class_lookup[init_class_id]})")
plt.imshow(init_image.astype(np.uint))
plt.title(f"Orginal Bild, Klassifiering: {class_lookup[init_class_id]} ({init_class_id})")
plt.show()
# Out:
# Init image class label: 866 (tractor)
# Init image class label: 105 (koala)

# %% [markdown]
# ## Skyddsåtgärder

# %% [markdown]
# Beskriv (i rapportens sektion 2.3) vilka säkerhetsåtgärd(er) ni valt som lämpliga för att skydda mot er attack. Motivera varför ni valt just de(n) metod(erna).

# %% [markdown]
# ## Implementation av skyddsåtgärder (frivilligt endast för A eller B)

# %% [markdown]
# Nedan fyller ni i er kod som implementerar skyddsmekanismen mot er attackmetod. Skriv även en summering av vad skyddsresultatet blev när ni implementerade metoden (beskriv detta i rapportens del 2.4).

# %% [markdown]
# ### Egna funktioner

# %%
# Samla era egna funktioner relaterade till säkerhetsåtgärden här
# Funktionerna ska kort beskrivas med docstrings och kommentarer så att man förstår syftet och implementationen
# Blir det många bör ni bryta ut dessa i en separat fil
from skimage.restoration import (denoise_wavelet, estimate_sigma)
import cv2 as cv

# %% [markdown]
# ### Förberedelser

# %%
# E.g. skapande av ny modell, etc.
adv_image = image.load_img("images/adv.png", target_size=(224, 224))
adv_image = image.img_to_array(adv_image)
avging = cv.blur(adv_image,(2,2))
# avging = denoise_wavelet(adv_image,convert2ycbcr=True,method='BayesShrink', mode='soft',sigma=0.01,channel_axis=-1)
#save the image to test folder
plt.imshow(avging.astype(np.uint))
plt.title("Denoised Image")
plt.show()
#save
avging = avging.astype(np.uint8)
plt.imsave("images/adv_tractor.jpeg", avging)

# avging = adv_image

init_class_id = np.argmax(model.predict(np.array([avging])))

#get accuracy
accuracy = model.predict(np.array([avging]))
print(f"Accuracy after attack: {accuracy[0][init_class_id]}")

#get accuracy
accuracy = model.predict(np.array([init_image]))
print(f"Accuracy before: {accuracy[0][init_class_id]}")

print(f"Init image class label: {init_class_id}")

plt.imshow(avging.astype(np.uint))
# Out:
# Accuracy after attack: 0.9927833080291748
# Accuracy before: 0.9999368190765381
# Init image class label: 105

# %% [markdown]
# ### Skydd

# %% [markdown]
# Beskriv säkerhetsåtgärden kortfattat här

# %%
# Implementation av skyddsåtgärd

# %% [markdown]
# ### Skyddsresultat

# %% [markdown]
# Bevisa och förklara era skyddsresultat i flytande text här

# %%
# Presentera skyddåtgärdens resultat m.h.a. kod här

# %% [markdown]
# # Referenser

# %% [markdown]
# Lista era referenser här. E.g. var ni hittat information om attacken, skyddsåtgärder eller bibliotekets dokumentation/repository.
